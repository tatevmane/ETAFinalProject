# %% [markdown]
# ## PCA Analysis

# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import nltk
import plotly_express as px
from numpy.linalg import norm
from scipy.linalg import eigh
import plotly.graph_objects as go
from sklearn.decomposition import PCA
from scipy.linalg import eigh
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation as LDA
import plotly_express as px
from gensim.models import word2vec
from sklearn.manifold import TSNE

import warnings
warnings.filterwarnings('ignore')

# %%
CORPUS = pd.read_csv("C:/Users/Student/Desktop/UVA/UVA '23 Spring/DS 5001/Final Project/CORPUS.csv")
LIB = pd.read_csv("C:/Users/Student/Desktop/UVA/UVA '23 Spring/DS 5001/Final Project/LIB.csv")
VOCAB = pd.read_csv("C:/Users/Student/Desktop/UVA/UVA '23 Spring/DS 5001/Final Project/VOCAB.csv")

# %%
CORPUS.sample(4)
# Out:
#         Unnamed: 0  text_num  para_num  sent_num  token_num  \
# 659014      659014       772         8         0         12
# 165006      165006       165         5         3         12
# 152455      152455       153        86         3          0
# 480235      480235       516         3         0         21
#
#                         pos_tuple  pos       token_str        term_str source
# 659014  ('investigations', 'NNS')  NNS  investigations  investigations   CNBC
# 165006              ('is', 'VBZ')  VBZ              is              is    CNN
# 152455               ('if', 'IN')   IN              if              if    CNN
# 480235             ('loan', 'NN')   NN            loan            loan   CNBC

# %%
LIB.sample(4)
# Out:
#     source_id        date                                                url  \
# 324       CNN  2020/11/23  https://www.cnn.com/2020/11/23/politics/joe-bi...
# 758      CNBC  2020/12/21  https://www.cnbc.com/2020/12/21/who-says-covid...
# 233       CNN  2020/12/30  https://www.cnn.com/2020/12/30/politics/treasu...
# 238       CNN  2020/12/09  https://www.cnn.com/2020/12/09/politics/melani...
#
#                                                  title  \
# 324  politic joe biden foreign policy national secu...
# 758   says covid mutate slow rate flu new strain uk...
# 233     politic treasury second round stimulus payment
# 238                       politic melania trump future
#
#                                                   text
# 324  President-elect Joe Biden on Monday unveiled a...
# 758  World Health Organization officials said Monda...
# 233  Americans can expect to start seeing $600 in t...
# 238  In mid-November, as President Donald Trump rai...

# %%
VOCAB.sample(4)
# Out:
#        term_str   n  n_chars         p          i max_pos  n_pos  stop  \
# 21540  sunshine   8        8  0.000010  16.621403      NN      2     0
# 24602    youths   1        6  0.000001  19.621403     NNS      1     0
# 6174     dating  12        6  0.000015  16.036440     VBG      2     0
# 13896   matchup   5        7  0.000006  17.299475      NN      1     0
#
#       stem_porter stem_snowball stem_lancaster
# 21540     sunshin       sunshin        sunshin
# 24602       youth         youth          youth
# 6174         date          date            dat
# 13896     matchup       matchup        matchup

# %%
tf_method = 'sum'         # sum, max, log, double_norm, raw, binary
tf_norm_k = .5            # only used for double_norm
idf_method = 'standard'   # standard, max, smooth
gradient_cmap = 'YlGnBu'  # YlGn, GnBu, YlGnBu; For tables; see https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html 


OHCO = ['source', 'text_num', 'para_num', 'sent_num', 'token_num']
SENTS = OHCO[:4]
PARAS = OHCO[:3]
ARTICLES = OHCO[:2]
SOURCES = OHCO[:1]

# %%
CORPUS = CORPUS.reset_index().set_index(OHCO).drop("index", axis=1)
CORPUS
# Out:
#                                              Unnamed: 0  \
# source text_num para_num sent_num token_num
# CNN    0        0        0        0                   0
#                                   1                   1
#                                   2                   2
#                                   3                   3
#                                   4                   4
# ...                                                 ...
# CNBC   989      17       2        19             806544
#                                   20             806545
#                                   21             806546
#                                   22             806547
#                                   23             806548
#
#                                                           pos_tuple  pos  \
# source text_num para_num sent_num token_num
# CNN    0        0        0        0                   ('two', 'CD')   CD
#                                   1                 ('more', 'JJR')  JJR
#                                   2              ('infants', 'NNS')  NNS
#                                   3                 ('have', 'VBP')  VBP
#                                   4           ('contracted', 'VBN')  VBN
# ...                                                             ...  ...
# CNBC   989      17       2        19              ('healing', 'NN')   NN
#                                   20               ('planet', 'NN')   NN
#                                   21                   ('to', 'TO')   TO
#                                   22               ('future', 'JJ')   JJ
#                                   23         ('generations', 'NNS')  NNS
#
#                                                token_str     term_str
# source text_num para_num sent_num token_num
# CNN    0        0        0        0                  two          two
#                                   1                 more         more
#                                   2              infants      infants
#                                   3                 have         have
#                                   4           contracted   contracted
# ...                                                  ...          ...
# CNBC   989      17       2        19             healing      healing
#                                   20              planet       planet
#                                   21                  to           to
#                                   22              future       future
#                                   23         generations  generations
#
# [806549 rows x 5 columns]

# %%
def BOW(df, bag):
    bow = df.groupby(bag+['term_str']).term_str.count().to_frame('n') 
    return bow

# %%
def calculate_tfidf(bow_table,tf_method):
    
    DTCM = bow_table.n.unstack().fillna(0).astype('int')
    
    if tf_method == 'sum':
        TF = DTCM.T / DTCM.T.sum()
    elif tf_method == 'max':
        TF = DTCM.T / DTCM.T.max()
    elif tf_method == 'log':
        TF = np.log2(1 + DTCM.T)
    elif tf_method == 'raw':
        TF = DTCM.T
    elif tf_method == 'double_norm':
        TF = DTCM.T / DTCM.T.max()
    elif tf_method == 'binary':
        TF = DTCM.T.astype('bool').astype('int')
    
    TF = TF.T
    
    # compute DF
    DF = DTCM.astype('bool').sum()
    
    # compute IDF
    N = DTCM.shape[0]
    
    if idf_method == 'standard':
        IDF = np.log2(N / DF)
    elif idf_method == 'max':
        IDF = np.log2(DF.max() / DF) 
    elif idf_method == 'smooth':
        IDF = np.log2((1 + N) / (1 +DF)) + 1
    
    # compute TFIDF
    TFIDF = TF * IDF
    
    return(TFIDF,TF,DF,IDF)

# %%
BOW_SOURCES = BOW(CORPUS, SOURCES)
BOW_ARTICLES = BOW(CORPUS, ARTICLES)

# %%
tfidf_articles, tf_articles, df_articles, idf_articles = calculate_tfidf(BOW_ARTICLES,'max')
tfidf_sources, tf_sources, df_sources, idf_sources = calculate_tfidf(BOW_SOURCES,'max')

# %%
tfidf_articles.mean().sort_values(ascending=False)\
    .head(20).to_frame('mean_tfidf').reset_index().join(VOCAB.max_pos).set_index("term_str")
# Out:
#            mean_tfidf max_pos
# term_str
# trump        0.093882      CD
# you          0.070173      CD
# your         0.069067      CD
# biden        0.064063      CD
# her          0.060828      CD
# his          0.057643      CD
# she          0.055750      CD
# i            0.055270      CD
# he           0.054128      CD
# s            0.050730      CD
# shares       0.049535      CD
# election     0.049435      CD
# president    0.045963      CD
# ballots      0.045220      CD
# company      0.044109      CD
# covid        0.042550      CD
# house        0.041066      CD
# tax          0.040644      CD
# said         0.040518      CD
# its          0.039436      CD

# %%
tfidf_sources.mean().sort_values(ascending=False)\
    .head(20).to_frame('mean_tfidf').reset_index().join(VOCAB.max_pos).set_index("term_str")
# Out:
#            mean_tfidf max_pos
# term_str
# thats        0.005644      CD
# cnbcs        0.005360      CD
# youre        0.004201      CD
# dow          0.003891      CD
# cramer       0.003866      CD
# premarket    0.003685      CD
# theres       0.003324      CD
# companys     0.002989      CD
# nasdaq       0.002938      CD
# im           0.002886      CD
# doesnt       0.002732      CD
# doesn        0.002695      CD
# theyre       0.002603      CD
# gottlieb     0.002526      CD
# hes          0.002087      CD
# maxwell      0.001984      CD
# yun          0.001933      CD
# weve         0.001855      CD
# falwell      0.001830      CD
# stevens      0.001752      CD

# %%
VOCAB = VOCAB.set_index("term_str")

# %% [markdown]
# ## By Article

# %%
BOW_ARTICLES['tf'] = tf_articles.stack()
BOW_ARTICLES['tfidf'] = tfidf_articles.stack()

# %%
VOCAB_articles = VOCAB.copy()
VOCAB_articles['df'] = df_articles
VOCAB_articles['idf'] = idf_articles
VOCAB_sources = VOCAB.copy()
VOCAB_sources['df'] = df_sources
VOCAB_sources['idf'] = idf_sources

# %%
VOCAB_articles['tfidf_mean'] = BOW_ARTICLES.groupby('term_str').tfidf.mean()
VOCAB_articles['tfidf_sum'] = tfidf_articles.sum()
VOCAB_articles['tfidf_median'] = BOW_ARTICLES.groupby('term_str').tfidf.median()
VOCAB_articles['tfidf_max'] = tfidf_articles.max()
VOCAB_articles['dfidf'] = VOCAB_articles.df * VOCAB_articles.idf

# %%
VOCAB_articles.sort_values('tfidf_mean', ascending = False)[['max_pos', 'i','tfidf_mean', 'tfidf_median', 'tfidf_max', 'dfidf']]
# Out:
#                max_pos          i  tfidf_mean  tfidf_median  tfidf_max  \
# term_str
# debatelocation      NN  15.036440    7.704220      7.704220   7.704220
# grissom             NN  16.621403    7.161028      7.161028   7.161028
# bruno               NN  14.920963    6.464817      6.464817   6.464817
# chopra              NN  16.299475    6.219553      6.219553   6.219553
# 2016event           CD  15.373475    6.099175      6.099175   6.099175
# ...                ...        ...         ...           ...        ...
# a                   DT   5.474516    0.010459      0.009778   0.024989
# of                  IN   5.385314    0.007383      0.007038   0.017594
# and                 CC   5.443282    0.006764      0.006097   0.016120
# the                 DT   4.140108    0.000000      0.000000   0.000000
# NaN                 JJ  18.621403         NaN           NaN        NaN
#
#                     dfidf
# term_str
# debatelocation   9.951285
# grissom         17.902569
# bruno           17.902569
# chopra           9.951285
# 2016event        9.951285
# ...                   ...
# a               24.314025
# of              17.206991
# and             15.781152
# the              0.000000
# NaN                   NaN
#
# [24696 rows x 6 columns]

# %% [markdown]
# ## PCA

# %%
TFIDF = BOW_ARTICLES['tfidf'].unstack(fill_value=0) 
VSHORT = VOCAB_articles[VOCAB_articles.max_pos.isin(['NN', 'VB', 'JJ'])].sort_values('dfidf', ascending=False).head(1000)
TFIDF = TFIDF[VSHORT.index]
TFIDF_L2 = (TFIDF.T / norm(TFIDF, 2, axis=1)).T
TFIDF_L2 = TFIDF_L2 - TFIDF_L2.mean()
COV = TFIDF_L2.T.dot(TFIDF_L2) / (TFIDF_L2.shape[0] - 1)
COV.head()
# Out:
# term_str      week     state         t      take      much  coronavirus  \
# term_str
# week      0.000958  0.000141 -0.000090 -0.000010 -0.000005     0.000151
# state     0.000141  0.001943  0.000025 -0.000018 -0.000023    -0.000048
# t        -0.000090  0.000025  0.001982  0.000084  0.000140    -0.000059
# take     -0.000010 -0.000018  0.000084  0.000342  0.000024     0.000020
# much     -0.000005 -0.000023  0.000140  0.000024  0.000584    -0.000024
#
# term_str     covid     house  election      make  ...     blood     panel  \
# term_str                                          ...
# week      0.000229  0.000177  0.000134 -0.000074  ... -0.000023  0.000025
# state    -0.000104 -0.000132  0.000706 -0.000088  ... -0.000016 -0.000023
# t        -0.000035 -0.000124  0.000234 -0.000043  ...  0.000097 -0.000034
# take      0.000090 -0.000061 -0.000029  0.000016  ...  0.000003  0.000021
# much     -0.000019 -0.000098 -0.000138  0.000067  ...  0.000032 -0.000012
#
# term_str    russia  atlantic     hotel   produce  giuliani    friend  \
# term_str
# week     -0.000044 -0.000005 -0.000001 -0.000021  0.000106 -0.000003
# state    -0.000030 -0.000048 -0.000030 -0.000014  0.000123 -0.000026
# t         0.000077  0.000033 -0.000011 -0.000011  0.000071  0.000144
# take     -0.000010 -0.000038 -0.000019 -0.000011  0.000001  0.000027
# much     -0.000015  0.000021 -0.000017  0.000029 -0.000064  0.000021
#
# term_str         worry      path
# term_str
# week      4.842219e-05  0.000005
# state    -9.620913e-06 -0.000022
# t         6.975898e-06 -0.000028
# take      2.128241e-07 -0.000012
# much      6.381934e-05  0.000015
#
# [5 rows x 1000 columns]

# %%
eig_vals, eig_vecs = eigh(COV)
EIG_VEC = pd.DataFrame(eig_vecs, index=COV.index, columns=COV.index)
EIG_VAL = pd.DataFrame(eig_vals, index=COV.index, columns=['eig_val'])
EIG_VAL.index.name = 'term_str'
colors = "Spectral"
EIG_VEC.iloc[:10, :10].style.background_gradient(cmap=colors)
# Out:
# <style type="text/css">
# #T_66306_row0_col0, #T_66306_row0_col2, #T_66306_row0_col3, #T_66306_row4_col6, #T_66306_row4_col9, #T_66306_row5_col7, #T_66306_row6_col8, #T_66306_row8_col1, #T_66306_row8_col4, #T_66306_row9_col5 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_66306_row0_col1, #T_66306_row1_col8, #T_66306_row2_col2, #T_66306_row3_col4, #T_66306_row3_col9, #T_66306_row4_col7, #T_66306_row6_col3, #T_66306_row7_col0, #T_66306_row7_col5, #T_66306_row9_col6 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_66306_row0_col4 {
#   background-color: #89d0a4;
#   color: #000000;
# }
# #T_66306_row0_col5, #T_66306_row1_col5 {
#   background-color: #60bba8;
#   color: #000000;
# }
# #T_66306_row0_col6 {
#   background-color: #8cd1a4;
#   color: #000000;
# }
# #T_66306_row0_col7 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_66306_row0_col8, #T_66306_row1_col3 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_66306_row0_col9, #T_66306_row2_col3, #T_66306_row5_col8 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_66306_row1_col0, #T_66306_row2_col6 {
#   background-color: #f7fcb2;
#   color: #000000;
# }
# #T_66306_row1_col1 {
#   background-color: #64c0a6;
#   color: #000000;
# }
# #T_66306_row1_col2 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_66306_row1_col4 {
#   background-color: #f2faaa;
#   color: #000000;
# }
# #T_66306_row1_col6 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_66306_row1_col7 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_66306_row1_col9 {
#   background-color: #f9fcb5;
#   color: #000000;
# }
# #T_66306_row2_col0 {
#   background-color: #f5fbaf;
#   color: #000000;
# }
# #T_66306_row2_col1 {
#   background-color: #94d4a4;
#   color: #000000;
# }
# #T_66306_row2_col4 {
#   background-color: #6bc4a5;
#   color: #000000;
# }
# #T_66306_row2_col5 {
#   background-color: #bae3a1;
#   color: #000000;
# }
# #T_66306_row2_col7, #T_66306_row8_col8 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_66306_row2_col8 {
#   background-color: #b61b48;
#   color: #f1f1f1;
# }
# #T_66306_row2_col9 {
#   background-color: #c3e79f;
#   color: #000000;
# }
# #T_66306_row3_col0 {
#   background-color: #ed6246;
#   color: #f1f1f1;
# }
# #T_66306_row3_col1 {
#   background-color: #56b0ad;
#   color: #f1f1f1;
# }
# #T_66306_row3_col2 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_66306_row3_col3 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_66306_row3_col5 {
#   background-color: #9cd7a4;
#   color: #000000;
# }
# #T_66306_row3_col6 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# #T_66306_row3_col7 {
#   background-color: #b5e1a2;
#   color: #000000;
# }
# #T_66306_row3_col8 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_66306_row4_col0 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_66306_row4_col1 {
#   background-color: #79c9a5;
#   color: #000000;
# }
# #T_66306_row4_col2 {
#   background-color: #c72e4c;
#   color: #f1f1f1;
# }
# #T_66306_row4_col3 {
#   background-color: #cb334d;
#   color: #f1f1f1;
# }
# #T_66306_row4_col4 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_66306_row4_col5 {
#   background-color: #d1ed9c;
#   color: #000000;
# }
# #T_66306_row4_col8 {
#   background-color: #5061aa;
#   color: #f1f1f1;
# }
# #T_66306_row5_col0 {
#   background-color: #d6ee9b;
#   color: #000000;
# }
# #T_66306_row5_col1 {
#   background-color: #fbfdb8;
#   color: #000000;
# }
# #T_66306_row5_col2 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_66306_row5_col3 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_66306_row5_col4 {
#   background-color: #66c2a5;
#   color: #000000;
# }
# #T_66306_row5_col5 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_66306_row5_col6 {
#   background-color: #91d3a4;
#   color: #000000;
# }
# #T_66306_row5_col9 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_66306_row6_col0, #T_66306_row8_col6 {
#   background-color: #eaf79e;
#   color: #000000;
# }
# #T_66306_row6_col1 {
#   background-color: #eff9a6;
#   color: #000000;
# }
# #T_66306_row6_col2 {
#   background-color: #f36b43;
#   color: #f1f1f1;
# }
# #T_66306_row6_col4 {
#   background-color: #54aead;
#   color: #f1f1f1;
# }
# #T_66306_row6_col5 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_66306_row6_col6 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_66306_row6_col7, #T_66306_row8_col0 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_66306_row6_col9 {
#   background-color: #f26944;
#   color: #f1f1f1;
# }
# #T_66306_row7_col1 {
#   background-color: #ecf7a1;
#   color: #000000;
# }
# #T_66306_row7_col2 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_66306_row7_col3, #T_66306_row7_col9 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_66306_row7_col4 {
#   background-color: #3d95b8;
#   color: #f1f1f1;
# }
# #T_66306_row7_col6 {
#   background-color: #df4e4b;
#   color: #f1f1f1;
# }
# #T_66306_row7_col7 {
#   background-color: #7ecca5;
#   color: #000000;
# }
# #T_66306_row7_col8 {
#   background-color: #c8e99e;
#   color: #000000;
# }
# #T_66306_row8_col2 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_66306_row8_col3, #T_66306_row9_col3 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_66306_row8_col5 {
#   background-color: #3990ba;
#   color: #f1f1f1;
# }
# #T_66306_row8_col7 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_66306_row8_col9 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_66306_row9_col0 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_66306_row9_col1 {
#   background-color: #e4f498;
#   color: #000000;
# }
# #T_66306_row9_col2 {
#   background-color: #d7414e;
#   color: #f1f1f1;
# }
# #T_66306_row9_col4 {
#   background-color: #99d6a4;
#   color: #000000;
# }
# #T_66306_row9_col7 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_66306_row9_col8 {
#   background-color: #e8f69b;
#   color: #000000;
# }
# #T_66306_row9_col9 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# </style>
# <table id="T_66306">
#   <thead>
#     <tr>
#       <th class="index_name level0" >term_str</th>
#       <th id="T_66306_level0_col0" class="col_heading level0 col0" >week</th>
#       <th id="T_66306_level0_col1" class="col_heading level0 col1" >state</th>
#       <th id="T_66306_level0_col2" class="col_heading level0 col2" >t</th>
#       <th id="T_66306_level0_col3" class="col_heading level0 col3" >take</th>
#       <th id="T_66306_level0_col4" class="col_heading level0 col4" >much</th>
#       <th id="T_66306_level0_col5" class="col_heading level0 col5" >coronavirus</th>
#       <th id="T_66306_level0_col6" class="col_heading level0 col6" >covid</th>
#       <th id="T_66306_level0_col7" class="col_heading level0 col7" >house</th>
#       <th id="T_66306_level0_col8" class="col_heading level0 col8" >election</th>
#       <th id="T_66306_level0_col9" class="col_heading level0 col9" >make</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >term_str</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66306_level0_row0" class="row_heading level0 row0" >week</th>
#       <td id="T_66306_row0_col0" class="data row0 col0" >0.158766</td>
#       <td id="T_66306_row0_col1" class="data row0 col1" >-0.166434</td>
#       <td id="T_66306_row0_col2" class="data row0 col2" >0.144215</td>
#       <td id="T_66306_row0_col3" class="data row0 col3" >0.164104</td>
#       <td id="T_66306_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_66306_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_66306_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_66306_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_66306_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_66306_row0_col9" class="data row0 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_66306_level0_row1" class="row_heading level0 row1" >state</th>
#       <td id="T_66306_row1_col0" class="data row1 col0" >-0.013736</

# %%
EIG_VEC_PAIRS = EIG_VEC.stack().sort_values(ascending=False).to_frame('covariance')
EIG_VEC_PAIRS.index.names = ['term1', 'term2']
EIG_VEC_PAIRS.head(20)
# Out:
#                      covariance
# term1    term2
# black    dozen         0.522584
# trump    path          0.490639
# security blood         0.442539
# tax      atlantic      0.440119
# black    smith         0.405701
# internet attend        0.356441
# social   blood         0.339415
# study    mr            0.317991
# supreme  tax           0.303695
# student  guilty        0.302439
# biden    path          0.298446
# activity nature        0.298039
# study    adjusted      0.290648
# straight attend        0.286605
# tax      panel         0.286511
# fox      original      0.285962
# deliver  attend        0.285960
# pence    internet      0.282104
# game     appearance    0.279836
# amazon   fund          0.279691

# %%
eig_vec_covar = EIG_VEC_PAIRS.sample(10000).sort_values('covariance', ascending=False).plot(rot=45, style='.', figsize=(10,5));

# %%
EIG_PAIRS = EIG_VAL.join(EIG_VEC.T)
EIG_PAIRS.sort_values('eig_val', ascending=False).head(10)
# Out:
#            eig_val      week     state         t      take      much  \
# term_str
# path      0.032172  0.001868  0.045520  0.045500 -0.005478 -0.007961
# worry     0.019628  0.002108  0.042799 -0.039933 -0.008777 -0.006942
# friend    0.018169  0.036516 -0.072569 -0.067598  0.003273 -0.015129
# giuliani  0.016974 -0.058619 -0.001265  0.062410 -0.003357 -0.018898
# produce   0.014041 -0.000819 -0.004462 -0.018727 -0.014866 -0.021154
# hotel     0.013440  0.053904  0.151065 -0.068526 -0.001260 -0.032664
# atlantic  0.012667 -0.022443  0.010729 -0.063105  0.012183  0.013051
# russia    0.010774 -0.014334  0.038729 -0.016228 -0.015889 -0.042359
# panel     0.010268 -0.038175  0.069941  0.030296 -0.024225  0.013319
# blood     0.009714 -0.028635 -0.037990 -0.019008  0.016974  0.029199
#
#           coronavirus     covid     house  election  ...     blood     panel  \
# term_str                                             ...
# path         0.012440 -0.013102  0.156552  0.173554  ... -0.000453 -0.000405
# worry       -0.118362 -0.196931 -0.088596  0.155403  ... -0.036073 -0.018020
# friend       0.078049  0.080955  0.184633 -0.001324  ... -0.005048  0.008437
# giuliani    -0.050216 -0.060383 -0.160347  0.071561  ...  0.002704 -0.000495
# produce     -0.034871 -0.086501  0.153851 -0.049573  ... -0.004861 -0.010042
# hotel        0.060054  0.105948 -0.062377  0.231962  ... -0.006892  0.010952
# atlantic     0.028851  0.055684 -0.098784 -0.081477  ... -0.008006  0.007568
# russia      -0.013087  0.035543  0.031482  0.036281  ... -0.002917  0.007851
# panel       -0.003286 -0.006755  0.058511  0.159299  ...  0.003749 -0.001822
# blood       -0.019029 -0.021630  0.005025  0.054616  ... -0.006864 -0.001218
#
#             russia  atlantic     hotel   produce  giuliani    friend  \
# term_str
# path      0.026669  0.015146  0.008929 -0.010773  0.039201  0.007037
# worry     0.018287 -0.005129  0.002634  0.003137 -0.006469  0.001115
# friend   -0.006090  0.012080 -0.010415  0.008031  0.016464 -0.008779
# giuliani  0.010634  0.014336  0.002305  0.003769  0.008895  0.010083
# produce  -0.002022 -0.006674  0.023112 -0.007305  0.030410 -0.000333
# hotel    -0.015544 -0.024521 -0.021823 -0.005731  0.023635 -0.019968
# atlantic  0.023140 -0.003502  0.025273  0.010561 -0.002823 -0.011881
# russia    0.018369  0.002837  0.004036  0.000972  0.023798 -0.014331
# panel    -0.028443  0.009490  0.020854  0.000554  0.031507  0.005634
# blood    -0.004284 -0.009530 -0.017816 -0.006956  0.028649 -0.000304
#
#              worry      path
# term_str
# path     -0.004083  0.003465
# worry     0.000403  0.006109
# friend   -0.006564  0.007351
# giuliani -0.015824 -0.004600
# produce  -0.009726 -0.003140
# hotel     0.001788 -0.002946
# atlantic -0.012279 -0.007231
# russia   -0.003104 -0.009007
# panel    -0.002755 -0.002339
# blood    -0.007586 -0.004129
#
# [10 rows x 1001 columns]

# %%
EIG_PAIRS['exp_var'] = np.round((EIG_PAIRS.eig_val / EIG_PAIRS.eig_val.sum()) * 100, 2)
EIG_PAIRS_VIZ = EIG_PAIRS.exp_var.sort_values(ascending=False).head().plot.bar(rot=45);

# %%
COMPS = EIG_PAIRS.sort_values('exp_var', ascending=False).head(10).reset_index(drop=True)
COMPS.index.name = 'comp_id'
COMPS.index = ["PC{}".format(i) for i in COMPS.index.tolist()]
COMPS.index.name = 'pc_id'
COMPS
# Out:
#         eig_val      week     state         t      take      much  \
# pc_id
# PC0    0.032172  0.001868  0.045520  0.045500 -0.005478 -0.007961
# PC1    0.019628  0.002108  0.042799 -0.039933 -0.008777 -0.006942
# PC2    0.018169  0.036516 -0.072569 -0.067598  0.003273 -0.015129
# PC3    0.016974 -0.058619 -0.001265  0.062410 -0.003357 -0.018898
# PC4    0.014041 -0.000819 -0.004462 -0.018727 -0.014866 -0.021154
# PC5    0.013440  0.053904  0.151065 -0.068526 -0.001260 -0.032664
# PC6    0.012667 -0.022443  0.010729 -0.063105  0.012183  0.013051
# PC7    0.010774 -0.014334  0.038729 -0.016228 -0.015889 -0.042359
# PC8    0.010268 -0.038175  0.069941  0.030296 -0.024225  0.013319
# PC9    0.009714 -0.028635 -0.037990 -0.019008  0.016974  0.029199
#
#        coronavirus     covid     house  election  ...     panel    russia  \
# pc_id                                             ...
# PC0       0.012440 -0.013102  0.156552  0.173554  ... -0.000405  0.026669
# PC1      -0.118362 -0.196931 -0.088596  0.155403  ... -0.018020  0.018287
# PC2       0.078049  0.080955  0.184633 -0.001324  ...  0.008437 -0.006090
# PC3      -0.050216 -0.060383 -0.160347  0.071561  ... -0.000495  0.010634
# PC4      -0.034871 -0.086501  0.153851 -0.049573  ... -0.010042 -0.002022
# PC5       0.060054  0.105948 -0.062377  0.231962  ...  0.010952 -0.015544
# PC6       0.028851  0.055684 -0.098784 -0.081477  ...  0.007568  0.023140
# PC7      -0.013087  0.035543  0.031482  0.036281  ...  0.007851  0.018369
# PC8      -0.003286 -0.006755  0.058511  0.159299  ... -0.001822 -0.028443
# PC9      -0.019029 -0.021630  0.005025  0.054616  ... -0.001218 -0.004284
#
#        atlantic     hotel   produce  giuliani    friend     worry      path  \
# pc_id
# PC0    0.015146  0.008929 -0.010773  0.039201  0.007037 -0.004083  0.003465
# PC1   -0.005129  0.002634  0.003137 -0.006469  0.001115  0.000403  0.006109
# PC2    0.012080 -0.010415  0.008031  0.016464 -0.008779 -0.006564  0.007351
# PC3    0.014336  0.002305  0.003769  0.008895  0.010083 -0.015824 -0.004600
# PC4   -0.006674  0.023112 -0.007305  0.030410 -0.000333 -0.009726 -0.003140
# PC5   -0.024521 -0.021823 -0.005731  0.023635 -0.019968  0.001788 -0.002946
# PC6   -0.003502  0.025273  0.010561 -0.002823 -0.011881 -0.012279 -0.007231
# PC7    0.002837  0.004036  0.000972  0.023798 -0.014331 -0.003104 -0.009007
# PC8    0.009490  0.020854  0.000554  0.031507  0.005634 -0.002755 -0.002339
# PC9   -0.009530 -0.017816 -0.006956  0.028649 -0.000304 -0.007586 -0.004129
#
#        exp_var
# pc_id
# PC0       3.47
# PC1       2.12
# PC2       1.96
# PC3       1.83
# PC4       1.51
# PC5       1.45
# PC6       1.37
# PC7       1.16
# PC8       1.11
# PC9       1.05
#
# [10 rows x 1002 columns]

# %%
LOADINGS = COMPS[COV.index].T
LOADINGS.index.name = 'term_str'
LOADINGS.head(10).style.background_gradient(cmap=colors)
# Out:
# <style type="text/css">
# #T_a244a_row0_col0 {
#   background-color: #c9314c;
#   color: #f1f1f1;
# }
# #T_a244a_row0_col1 {
#   background-color: #eff9a6;
#   color: #000000;
# }
# #T_a244a_row0_col2 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_a244a_row0_col3 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_a244a_row0_col4 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_a244a_row0_col5 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_a244a_row0_col6 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_a244a_row0_col7 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_a244a_row0_col8, #T_a244a_row1_col2, #T_a244a_row1_col9, #T_a244a_row2_col5, #T_a244a_row6_col0, #T_a244a_row6_col1, #T_a244a_row6_col4, #T_a244a_row7_col3, #T_a244a_row7_col6, #T_a244a_row9_col7 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_a244a_row0_col9 {
#   background-color: #d43d4f;
#   color: #f1f1f1;
# }
# #T_a244a_row1_col0, #T_a244a_row2_col0 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_a244a_row1_col1 {
#   background-color: #b5e1a2;
#   color: #000000;
# }
# #T_a244a_row1_col3 {
#   background-color: #b3e0a2;
#   color: #000000;
# }
# #T_a244a_row1_col4 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_a244a_row1_col5 {
#   background-color: #94d4a4;
#   color: #000000;
# }
# #T_a244a_row1_col6 {
#   background-color: #a4daa4;
#   color: #000000;
# }
# #T_a244a_row1_col7, #T_a244a_row6_col6, #T_a244a_row7_col2, #T_a244a_row7_col4, #T_a244a_row8_col0, #T_a244a_row8_col1, #T_a244a_row8_col3, #T_a244a_row8_col5, #T_a244a_row8_col8, #T_a244a_row8_col9 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_a244a_row1_col8 {
#   background-color: #f3faac;
#   color: #000000;
# }
# #T_a244a_row2_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_a244a_row2_col2 {
#   background-color: #a70b44;
#   color: #f1f1f1;
# }
# #T_a244a_row2_col3 {
#   background-color: #4d65ad;
#   color: #f1f1f1;
# }
# #T_a244a_row2_col4 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_a244a_row2_col6 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_a244a_row2_col7, #T_a244a_row3_col7, #T_a244a_row7_col9 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_a244a_row2_col8 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_a244a_row2_col9, #T_a244a_row4_col7, #T_a244a_row5_col9 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_a244a_row3_col0 {
#   background-color: #b41947;
#   color: #f1f1f1;
# }
# #T_a244a_row3_col1 {
#   background-color: #f7fcb2;
#   color: #000000;
# }
# #T_a244a_row3_col2 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_a244a_row3_col3 {
#   background-color: #b8e2a1;
#   color: #000000;
# }
# #T_a244a_row3_col4 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_a244a_row3_col5, #T_a244a_row4_col2, #T_a244a_row5_col1 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_a244a_row3_col6 {
#   background-color: #9fd8a4;
#   color: #000000;
# }
# #T_a244a_row3_col8 {
#   background-color: #c52c4b;
#   color: #f1f1f1;
# }
# #T_a244a_row3_col9 {
#   background-color: #e8f69b;
#   color: #000000;
# }
# #T_a244a_row4_col0 {
#   background-color: #ad1246;
#   color: #f1f1f1;
# }
# #T_a244a_row4_col1 {
#   background-color: #f5fbaf;
#   color: #000000;
# }
# #T_a244a_row4_col3 {
#   background-color: #dff299;
#   color: #000000;
# }
# #T_a244a_row4_col4 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_a244a_row4_col5 {
#   background-color: #da464d;
#   color: #f1f1f1;
# }
# #T_a244a_row4_col6, #T_a244a_row4_col9 {
#   background-color: #99d6a4;
#   color: #000000;
# }
# #T_a244a_row4_col8 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_a244a_row5_col0, #T_a244a_row9_col2 {
#   background-color: #e1504b;
#   color: #f1f1f1;
# }
# #T_a244a_row5_col2 {
#   background-color: #eaf79e;
#   color: #000000;
# }
# #T_a244a_row5_col3 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_a244a_row5_col4 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_a244a_row5_col5 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_a244a_row5_col6 {
#   background-color: #58b2ac;
#   color: #f1f1f1;
# }
# #T_a244a_row5_col7, #T_a244a_row7_col8 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_a244a_row5_col8, #T_a244a_row6_col9 {
#   background-color: #ed6246;
#   color: #f1f1f1;
# }
# #T_a244a_row6_col2 {
#   background-color: #e7f59a;
#   color: #000000;
# }
# #T_a244a_row6_col3 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_a244a_row6_col5 {
#   background-color: #ebf7a0;
#   color: #000000;
# }
# #T_a244a_row6_col7 {
#   background-color: #525fa9;
#   color: #f1f1f1;
# }
# #T_a244a_row6_col8 {
#   background-color: #e75948;
#   color: #f1f1f1;
# }
# #T_a244a_row7_col0 {
#   background-color: #3682ba;
#   color: #f1f1f1;
# }
# #T_a244a_row7_col1 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_a244a_row7_col5 {
#   background-color: #a90d45;
#   color: #f1f1f1;
# }
# #T_a244a_row7_col7 {
#   background-color: #3f77b5;
#   color: #f1f1f1;
# }
# #T_a244a_row8_col2 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_a244a_row8_col4 {
#   background-color: #e55749;
#   color: #f1f1f1;
# }
# #T_a244a_row8_col6 {
#   background-color: #d8434e;
#   color: #f1f1f1;
# }
# #T_a244a_row8_col7 {
#   background-color: #545ca8;
#   color: #f1f1f1;
# }
# #T_a244a_row9_col0 {
#   background-color: #a00343;
#   color: #f1f1f1;
# }
# #T_a244a_row9_col1 {
#   background-color: #f8fcb4;
#   color: #000000;
# }
# #T_a244a_row9_col3 {
#   background-color: #d3ed9c;
#   color: #000000;
# }
# #T_a244a_row9_col4, #T_a244a_row9_col8 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_a244a_row9_col5 {
#   background-color: #d7414e;
#   color: #f1f1f1;
# }
# #T_a244a_row9_col6 {
#   background-color: #7ccaa5;
#   color: #000000;
# }
# #T_a244a_row9_col9 {
#   background-color: #a2d9a4;
#   color: #000000;
# }
# </style>
# <table id="T_a244a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >pc_id</th>
#       <th id="T_a244a_level0_col0" class="col_heading level0 col0" >PC0</th>
#       <th id="T_a244a_level0_col1" class="col_heading level0 col1" >PC1</th>
#       <th id="T_a244a_level0_col2" class="col_heading level0 col2" >PC2</th>
#       <th id="T_a244a_level0_col3" class="col_heading level0 col3" >PC3</th>
#       <th id="T_a244a_level0_col4" class="col_heading level0 col4" >PC4</th>
#       <th id="T_a244a_level0_col5" class="col_heading level0 col5" >PC5</th>
#       <th id="T_a244a_level0_col6" class="col_heading level0 col6" >PC6</th>
#       <th id="T_a244a_level0_col7" class="col_heading level0 col7" >PC7</th>
#       <th id="T_a244a_level0_col8" class="col_heading level0 col8" >PC8</th>
#       <th id="T_a244a_level0_col9" class="col_heading level0 col9" >PC9</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >term_str</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a244a_level0_row0" class="row_heading level0 row0" >week</th>
#       <td id="T_a244a_row0_col0" class="data row0 col0" >0.001868</td>
#       <td id="T_a244a_row0_col1" class="data row0 col1" >0.002108</td>
#       <td id="T_a244a_row0_col2" class="data row0 col2" >0.036516</td>
#       <td id="T_a244a_row0_col3" class="data row0 col3" >-0.058619</td>
#       <td id="T_a244a_row0_col4" class="data row0 col4" >-0.000819</td>
#       <td id="T_a244a_row0_col5" class="data row0 col5" >0.053904</td>
#       <td id="T_a244a_row0_col6" class="data row0 col6" >-0.022443</td>
#       <td id="T_a244a_row0_col7" class="data row0 col7" >-0.014334</td>
#       <td id="T_a244a_row0_col8" class="data row0 col8" >-0.038175</td>
#       <td id="T_a244a_row0_col9" class="data row0 col9" >-0.028635</td>
#     </tr>
#     <tr>
#       <th id="T_a244a_level0_row1" class="row_heading level0 row1" >state</th>
#       <td id="T_a244a_row1_col0" class="data row1 col0" >0.045520</td>
#       <td id="T_a244a_row1_col1" class="data row1 col1" >0.042799</td>
#       <td id="T_a244a_row1_col2" class="data

# %%
top_terms = []
for i in range(10):
    for j in [0, 1]:
        comp_str = ' '.join(LOADINGS.sort_values(f'PC{i}', ascending=bool(j)).head(10).index.to_list())
        top_terms.append((f"PC{i}", j, comp_str))
COMP_GLOSS = pd.DataFrame(top_terms).set_index([0,1]).unstack()
COMP_GLOSS.index.name = 'comp_id'
COMP_GLOSS.columns = COMP_GLOSS.columns.droplevel(0) 
COMP_GLOSS = COMP_GLOSS.rename(columns={0:'pos', 1:'neg'})
COMP_GLOSS
# Out:
# 1                                                      pos  \
# comp_id
# PC0      trump biden president election white house cam...
# PC1      biden tax election stock trump share company r...
# PC2      stock house white positive trump share company...
# PC3      police company black share stock biden county ...
# PC4      quarantine police positive house white court m...
# PC5      court election mail vote state vaccine voting ...
# PC6      tax quarantine trump york vaccine income manha...
# PC7      police vaccine tax security revenue social bla...
# PC8      tax mail election voting income county vote ea...
# PC9      security social revenue age check share quaran...
#
# 1                                                      neg
# comp_id
# PC0      company stock share trading market quarter rev...
# PC1      virus covid positive cdc health dr vaccine dis...
# PC2      police tax court black income attorney county ...
# PC3      tax stimulus relief income aid bill unemployme...
# PC4      biden vaccine health debate u climate cdc covi...
# PC5      i security trump social tax white debate polic...
# PC6      black police relief stimulus pelosi senate aid...
# PC7      quarantine biden debate i negative guilty manh...
# PC8      police vaccine biden department quarantine att...
# PC9            tax police market i p black dow york u rate
